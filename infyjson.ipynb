# %%
import json
import pandas

df = pandas.read_json('INFY.json')
df
# Out:
#                                                                  dataset
# collapse                                                            None
# column_index                                                        None
# column_names           [Date, Open, High, Low, Last, Close, Total Tra...
# data                   [[2018-04-10, 1112.0, 1124.5, 1105.4, 1114.65,...
# database_code                                                        NSE
# database_id                                                           33
# dataset_code                                                        INFY
# description            Historical prices for Infosys Limited<br><br>N...
# end_date                                                      2018-04-10
# frequency                                                          daily
# id                                                                  6309
# limit                                                               None
# ...

# %%
df1 = pandas.DataFrame(df['dataset']['data'], columns = df['dataset']['column_names'])

# %%
df1
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     2018-04-10  1112.00  1124.50  1105.40  1114.65  1113.40
# 1     2018-04-09  1125.00  1125.80  1106.55  1111.45  1111.25
# 2     2018-04-06  1143.00  1146.00  1122.10  1127.55  1127.00
# 3     2018-04-05  1139.55  1151.30  1129.10  1146.05  1147.55
# 4     2018-04-04  1144.00  1144.55  1120.00  1122.70  1124.20
# 5     2018-04-03  1134.70  1143.55  1128.10  1139.40  1140.45
# 6     2018-04-02  1141.00  1149.55  1121.30  1136.70  1137.15
# 7     2018-03-28  1150.75  1150.75  1126.25  1140.00  1131.80
# 8     2018-03-27  1160.00  1161.30  1150.10  1152.10  1154.00
# 9     2018-03-26  1166.90  1166.90  1144.00  1155.60  1155.25
# 10    2018-03-23  1147.00  1173.80  1142.35  1165.00  1167.60
# 11    2018-03-22  1164.50  1177.45  1155.30  1156.00  1161.30
# 12    2018-03-21  1170.00  1175.50  1162.20  1166.20  1167.50
# 13    2018-03-20  1148.60  1170.00  1148.60  1164.55  1164.55
# ...
